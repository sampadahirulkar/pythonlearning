# %% [markdown]
# <a href="https://colab.research.google.com/github/sampadahirulkar/pythonlearning/blob/main/variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
price = 10
print(price)
# Out:
# 10

# %% [markdown]
# python assigned the value 10 to 'price'

# %%
price = 10
price = 20
print(price)
# Out:
# 20

# %% [markdown]
# python first assigned the value 10, and then 20 (so finally 20) because python processes code line by line
